# %% [markdown]
# # Topic 13: Tries
#
# ## Learning Objectives
# - Understand trie (prefix tree) data structure
# - Implement insert, search, and prefix matching
# - Solve word search and autocomplete problems
#
# ---

# %% [markdown]
# ## 1. Trie Basics
#
# ### Operations
# - Insert: O(m) where m is word length
# - Search: O(m)
# - Prefix search: O(m)
#
# ### Structure
# ```python
# class TrieNode:
#     def __init__(self):
#         self.children = {}  # char -> TrieNode
#         self.is_end = False
# ```

# %% [markdown]
# ---
#
# ## 2. Exercises
#
# ### Setup

# %%
import sys

sys.path.insert(0, "..")
from dsa_checker import check

# %% [markdown]
# ---
#
# ### Exercise 1: Implement Trie
# **Difficulty:** ⭐⭐ Medium
#
# **Problem:** Implement a trie (prefix tree) with insert, search, and startsWith methods.
#
# **Target Complexity:** O(m) for each operation (m = word length)
#
# **Examples:**
# ```
# trie = Trie()
# trie.insert("apple")
# trie.search("apple")   # True
# trie.search("app")     # False
# trie.startsWith("app") # True
# trie.insert("app")
# trie.search("app")     # True
# ```
#
# ---
#
# **🧠 Think About:**
# - What does each node represent?
# - How do you distinguish between a complete word and a prefix?
# - What data structure stores children nodes?
#
# **⚠️ Edge Cases:**
# - Empty string
# - Word is prefix of another
# - Prefix matches but word doesn't exist
#
# <details>
# <summary>💡 Hint</summary>
# Each node has children (dict or array of 26) and an "is_end" flag to mark complete words.
# </details>

# %%
class Trie:
    def __init__(self):
        pass

    def insert(self, word: str) -> None:
        pass

    def search(self, word: str) -> bool:
        pass

    def startsWith(self, prefix: str) -> bool:
        pass


def implement_trie():
    return Trie

# %%
check(implement_trie)

# %% [markdown]
# ---
#
# ### Exercise 2: Word Search II
# **Difficulty:** ⭐⭐⭐ Hard
#
# **Problem:** Given a 2D board and a list of words, find all words that exist in the board. Words can be constructed from adjacent cells (horizontally or vertically). Each cell may only be used once per word.
#
# **Constraints:**
# - Board dimensions: 1 <= m, n <= 12
# - Each cell contains a lowercase letter
# - 1 <= words.length <= 3 * 10^4
#
# **Examples:**
# ```
# Input: board = [["o","a","a","n"],["e","t","a","e"],["i","h","k","r"],["i","f","l","v"]],
#        words = ["oath","pea","eat","rain"]
# Output: ["eat","oath"]
# ```

# %%
def word_search_ii(board: list[list[str]], words: list[str]) -> list[str]:
    """Find all words from list that exist in board."""
    pass

# %%
check(word_search_ii)

# %% [markdown]
# ---
#
# ### Exercise 3: Add and Search Word
# **Difficulty:** ⭐⭐ Medium
#
# **Problem:** Design a data structure that supports adding words and searching with '.' as a wildcard that matches any letter.
#
# **Examples:**
# ```
# addWord("bad")
# addWord("dad")
# search("pad")  # False
# search("bad")  # True
# search(".ad")  # True
# search("b..")  # True
# ```

# %%
class WordDictionary:
    def __init__(self):
        pass

    def addWord(self, word: str) -> None:
        pass

    def search(self, word: str) -> bool:
        """word may contain '.' which matches any character."""
        pass


def add_and_search_word():
    return WordDictionary

# %%
check(add_and_search_word)

# %% [markdown]
# ---
#
# ### Exercise 4: Replace Words
# **Difficulty:** ⭐⭐ Medium
#
# **Problem:** Replace words in a sentence with their shortest root from a dictionary.
#
# **Examples:**
# ```
# Input: dictionary = ["cat", "bat", "rat"], sentence = "the cattle was rattled by the battery"
# Output: "the cat was rat by the bat"
# ```

# %%
def replace_words(dictionary: list[str], sentence: str) -> str:
    """Replace words with their shortest root from dictionary."""
    pass

# %%
check(replace_words)

# %% [markdown]
# ---
#
# ### Exercise 5: Longest Word in Dictionary
# **Difficulty:** ⭐⭐ Medium
#
# **Problem:** Find the longest word that can be built one character at a time by other words in the dictionary. If tie, return lexicographically smallest.
#
# **Examples:**
# ```
# Input: words = ["w", "wo", "wor", "worl", "world"]
# Output: "world"  # Each prefix exists
#
# Input: words = ["a", "banana", "app", "appl", "ap", "apply", "apple"]
# Output: "apple"  # "apple" and "apply" tie, "apple" is smaller
# ```

# %%
def longest_word(words: list[str]) -> str:
    """Find longest word that can be built one char at a time."""
    pass

# %%
check(longest_word)

# %% [markdown]
# ---
#
# ### Exercise 6: Map Sum Pairs
# **Difficulty:** ⭐⭐ Medium
#
# **Problem:** Implement a MapSum class with insert(key, val) and sum(prefix) that returns the sum of all values whose keys start with the given prefix.
#
# **Examples:**
# ```
# insert("apple", 3)
# sum("ap")      # Returns 3
# insert("app", 2)
# sum("ap")      # Returns 5 (3 + 2)
# ```

# %%
class MapSum:
    def __init__(self):
        pass

    def insert(self, key: str, val: int) -> None:
        pass

    def sum(self, prefix: str) -> int:
        """Return sum of values for keys starting with prefix."""
        pass


def map_sum():
    return MapSum

# %%
check(map_sum)

# %% [markdown]
# ---
#
# ## Summary
#
# - Tries excel at prefix-based operations
# - Space-efficient for dictionary of words
# - Combine with DFS for word search problems
#
# ## Next Steps
# Continue to **Topic 14: Union-Find**
