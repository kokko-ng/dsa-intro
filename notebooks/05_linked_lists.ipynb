# %% [markdown]
# # Topic 05: Linked Lists
#
# ## Learning Objectives
# - Understand singly and doubly linked list structures
# - Master pointer manipulation techniques
# - Solve classic linked list problems
#
# ---

# %% [markdown]
# ## 1. Linked List Basics
#
# ### Operations
# | Operation | Time |
# |-----------|------|
# | Access by index | O(n) |
# | Insert at head | O(1) |
# | Insert at tail | O(n) or O(1) with tail ptr |
# | Delete node | O(1) if have reference |
# | Search | O(n) |
#
# ### Key Techniques
# - **Dummy head**: Simplifies edge cases
# - **Two pointers**: Fast/slow for cycle detection, middle finding
# - **Reversal**: Iterative or recursive

# %% [markdown]
# ---
#
# ## 2. Exercises
#
# ### Setup

# %%
import sys
sys.path.insert(0, '..')
from dsa_checker import check
from data_structures import ListNode, create_linked_list, linked_list_to_list

# %% [markdown]
# ---
#
# ### Exercise 1: Reverse Linked List
# **Difficulty:** ⭐ Easy
#
# **Problem:** Reverse a singly linked list.
#
# **Target Complexity:** O(n) time, O(1) space
#
# **Examples:**
# ```
# Input: 1 -> 2 -> 3 -> 4 -> 5
# Output: 5 -> 4 -> 3 -> 2 -> 1
# ```
#
# ---
#
# **🧠 Think About:**
# - What information do you need to save before changing a pointer?
# - How do you "flip" a pointer to point backward?
#
# **⚠️ Edge Cases:**
# - Empty list
# - Single node
#
# <details>
# <summary>💡 Hint 1</summary>
# You need to track three nodes: previous, current, and next.
# </details>
#
# <details>
# <summary>💡 Hint 2</summary>
# Save the next pointer before overwriting it, then move all pointers forward.
# </details>

# %%
def reverse_list(head: ListNode) -> ListNode:
    """
    Reverse the linked list.
    """
    # Your code here
    pass

# %%
check(reverse_list)

# %% [markdown]
# ---
#
# ### Exercise 2: Merge Two Sorted Lists
# **Difficulty:** ⭐ Easy
#
# **Problem:** Merge two sorted linked lists into one sorted list.
#
# **Target Complexity:** O(n + m) time, O(1) space
#
# **Examples:**
# ```
# Input: 1 -> 2 -> 4, 1 -> 3 -> 4
# Output: 1 -> 1 -> 2 -> 3 -> 4 -> 4
# ```
#
# ---
#
# **🧠 Think About:**
# - How do you decide which node comes next?
# - What simplifies handling the "first node" case?
#
# **⚠️ Edge Cases:**
# - One or both lists empty
# - Lists of different lengths
#
# <details>
# <summary>💡 Hint 1</summary>
# A dummy head node simplifies the logic — you don't need special handling for the first node.
# </details>
#
# <details>
# <summary>💡 Hint 2</summary>
# Compare heads, attach the smaller one, advance that pointer. Handle remaining nodes after one list is exhausted.
# </details>

# %%
def merge_two_lists(list1: ListNode, list2: ListNode) -> ListNode:
    """
    Merge two sorted lists.
    """
    # Your code here
    pass

# %%
check(merge_two_lists)

# %% [markdown]
# ---
#
# ### Exercise 3: Linked List Cycle
# **Difficulty:** ⭐ Easy
#
# **Problem:** Detect if a linked list has a cycle.
#
# **Target Complexity:** O(n) time, O(1) space
#
# **Examples:**
# ```
# Input: 3 -> 2 -> 0 -> -4 (cycle back to 2)
# Output: True
#
# Input: 1 -> 2 -> None
# Output: False
# ```
#
# ---
#
# **🧠 Think About:**
# - If you traverse normally, how do you know you're in a cycle?
# - Can two pointers moving at different speeds help?
#
# **⚠️ Edge Cases:**
# - Empty list
# - Single node with no cycle
# - Cycle at the head
#
# <details>
# <summary>💡 Hint</summary>
# Use slow (1 step) and fast (2 steps) pointers. If there's a cycle, they will meet.
# </details>

# %%
def has_cycle(head: ListNode) -> bool:
    """
    Detect if linked list has a cycle.
    """
    # Your code here
    pass

# %%
check(has_cycle)

# %% [markdown]
# ---
#
# ### Exercise 4: Remove Nth Node From End
# **Difficulty:** ⭐⭐ Medium
#
# **Problem:** Remove the nth node from the end of the list.
#
# **Target Complexity:** O(n) time, O(1) space (one pass)
#
# **Examples:**
# ```
# Input: 1 -> 2 -> 3 -> 4 -> 5, n = 2
# Output: 1 -> 2 -> 3 -> 5  # removed 4
# ```
#
# ---
#
# **🧠 Think About:**
# - How can you find the nth node from the end in one pass?
# - If you have two pointers n nodes apart, what happens when one reaches the end?
#
# **⚠️ Edge Cases:**
# - Remove the head node
# - Single node list
# - n equals list length
#
# <details>
# <summary>💡 Hint 1</summary>
# Use a dummy node before head to handle removing the head itself.
# </details>
#
# <details>
# <summary>💡 Hint 2</summary>
# Move fast pointer n steps ahead, then move both until fast reaches the end.
# </details>

# %%
def remove_nth_from_end(head: ListNode, n: int) -> ListNode:
    """
    Remove nth node from end. Return new head.
    """
    # Your code here
    pass

# %%
check(remove_nth_from_end)

# %% [markdown]
# ---
#
# ### Exercise 5: Middle of Linked List
# **Difficulty:** ⭐ Easy
#
# **Problem:** Find the middle node. For even length, return the second middle.
#
# **Target Complexity:** O(n) time, O(1) space
#
# **Examples:**
# ```
# Input: 1 -> 2 -> 3 -> 4 -> 5
# Output: Node 3
#
# Input: 1 -> 2 -> 3 -> 4
# Output: Node 3 (second middle)
# ```
#
# ---
#
# **🧠 Think About:**
# - When does a pointer reach the middle?
# - If one pointer moves twice as fast, where is the slow one when fast reaches the end?
#
# **⚠️ Edge Cases:**
# - Single node
# - Two nodes
#
# <details>
# <summary>💡 Hint</summary>
# Slow moves 1 step, fast moves 2 steps. When fast reaches the end, slow is at the middle.
# </details>

# %%
def find_middle(head: ListNode) -> ListNode:
    """
    Find middle node (second middle if even length).
    """
    # Your code here
    pass

# %%
check(find_middle)

# %% [markdown]
# ---
#
# ### Exercise 6: Palindrome Linked List
# **Difficulty:** ⭐⭐ Medium
#
# **Problem:** Check if a linked list represents a palindrome.
#
# **Target Complexity:** O(n) time, O(1) space
#
# **Examples:**
# ```
# Input: 1 -> 2 -> 2 -> 1
# Output: True
#
# Input: 1 -> 2
# Output: False
# ```
#
# ---
#
# **🧠 Think About:**
# - To check a palindrome, you need to compare front and back. How do you access the back efficiently?
# - Can you use techniques from earlier exercises (find middle, reverse)?
#
# **⚠️ Edge Cases:**
# - Single node
# - Two nodes
# - Odd vs even length
#
# <details>
# <summary>💡 Hint 1</summary>
# Find the middle, reverse the second half, then compare both halves.
# </details>
#
# <details>
# <summary>💡 Hint 2</summary>
# You've already solved "find middle" and "reverse list" — combine them!
# </details>

# %%
def is_palindrome_list(head: ListNode) -> bool:
    """
    Check if linked list is a palindrome.
    """
    # Your code here
    pass

# %%
check(is_palindrome_list)

# %% [markdown]
# ---
#
# ### Exercise 7: Add Two Numbers
# **Difficulty:** ⭐⭐ Medium
#
# **Problem:** Numbers are stored in reverse order (1's digit first). Add them and return as linked list.
#
# **Target Complexity:** O(max(n, m)) time
#
# **Examples:**
# ```
# Input: 2 -> 4 -> 3 (342) + 5 -> 6 -> 4 (465)
# Output: 7 -> 0 -> 8 (807)
# ```
#
# ---
#
# **🧠 Think About:**
# - How is this similar to adding numbers by hand?
# - What do you need to track between digits?
#
# **⚠️ Edge Cases:**
# - Different length numbers
# - Carry at the end (e.g., 99 + 1 = 100)
# - One list is empty
#
# <details>
# <summary>💡 Hint</summary>
# Traverse both lists simultaneously, sum digits plus carry, create new nodes. Don't forget the final carry!
# </details>

# %%
def add_two_numbers(l1: ListNode, l2: ListNode) -> ListNode:
    """
    Add two numbers represented as linked lists.
    """
    # Your code here
    pass

# %%
check(add_two_numbers)

# %% [markdown]
# ---
#
# ### Exercise 8: Reorder List
# **Difficulty:** ⭐⭐ Medium
#
# **Problem:** Reorder: L0 → Ln → L1 → Ln-1 → L2 → Ln-2 → …
#
# **Target Complexity:** O(n) time, O(1) space
#
# **Examples:**
# ```
# Input: 1 -> 2 -> 3 -> 4
# Output: 1 -> 4 -> 2 -> 3
#
# Input: 1 -> 2 -> 3 -> 4 -> 5
# Output: 1 -> 5 -> 2 -> 4 -> 3
# ```
#
# ---
#
# **🧠 Think About:**
# - You need to interleave from front and back. How do you access nodes from the back?
# - Can you break this into sub-problems you've already solved?
#
# **⚠️ Edge Cases:**
# - Two or fewer nodes
# - Odd vs even length
#
# <details>
# <summary>💡 Hint</summary>
# Three steps: (1) Find middle, (2) Reverse second half, (3) Merge alternating nodes from both halves.
# </details>

# %%
def reorder_list(head: ListNode) -> None:
    """
    Reorder list in-place.
    """
    # Your code here
    pass

# %%
check(reorder_list)

# %% [markdown]
# ---
#
# ## Summary
#
# - Use dummy nodes to handle edge cases
# - Fast/slow pointers for cycle detection and middle finding
# - Practice in-place reversal
#
# ## Next Steps
# Continue to **Topic 06: Stacks & Queues**
